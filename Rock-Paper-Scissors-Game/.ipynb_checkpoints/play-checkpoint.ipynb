# %%
import random 

def win():
  return "Congratulations, You Win! Want to start a new game?"

def lose():
  return "You Lose! Want to start a new game?"

if __name__ == "__main__":
    
    while(True):
      print("""
            Enter r for Rock, 
                  s for Scissors, 
                  p for Paper
            """)
      player_1 = input("Player 1: ")
      player_type = input("Press c for computer to play or h for human to play:")

      if player_type == 'h':
        player_2 = input("Player 2:")
      else:
        player_2 = random.choice(['r', 's', 'p'])

      if player_1 == 'r' and player_2 == 's':
        print(win())
      elif player_1 == 'r' and player_2 == 'p':
        print(lose())
      elif player_1 == 'r' and player_2 == 'r':
        print("Draw! try again")

      if player_1 == 's' and player_2 == 'r':
        print(lose())
      elif player_1 == 's' and player_2 == 'p':
        print(win())
      elif player_1 == 's' and player_2 == 's':
        print("Draw! try again")

      if player_1 == 'p' and player_2 == 'r':
        print(win())
      elif player_1 == 'p' and player_2 == 's':
        print(lose())
      elif player_1 == 'p' and player_2 == 'p':
        print("Draw! try again")
# Out:
#             Enter r for Rock,
#                   s for Scissors,
#                   p for Paper
#
# Player 1: r
# Press c for computer to play or h for human to play:h
# Player 2:r
# Draw! try again
#
#             Enter r for Rock,
#                   s for Scissors,
#                   p for Paper
#
# Player 1: r
# Press c for computer to play or h for human to play:h
# Player 2:s
# Congratulations, You Win! Want to start a new game?
#
#             Enter r for Rock,
#                   s for Scissors,
#                   p for Paper
#
# Player 1: r
# Press c for computer to play or h for human to play:h
# Player 2:p
# You Lose! Want to start a new game?
#
#             Enter r for Rock,
#                   s for Scissors,
#                   p for Paper
#
# Player 1: r
# Press c for computer to play or h for human to play:c
# You Lose! Want to start a new game?
#
#             Enter r for Rock,
#                   s for Scissors,
#                   p for Paper
#
# Player 1: r
# Press c for computer to play or h for human to play:c
# You Lose! Want to start a new game?
#
#             Enter r for Rock,
#                   s for Scissors,
#                   p for Paper
#
# Player 1: r
# Press c for computer to play or h for human to play:c
# Draw! try again
#
#             Enter r for Rock,
#                   s for Scissors,
#                   p for Paper
#
# Player 1: r
# Press c for computer to play or h for human to play:c
# You Lose! Want to start a new game?
#
#             Enter r for Rock,
#                   s for Scissors,
#                   p for Paper
#
# Player 1: r
# Press c for computer to play or h for human to play:c
# You Lose! Want to start a new game?
#
#             Enter r for Rock,
#                   s for Scissors,
#                   p for Paper
#
# Player 1: r
# Press c for computer to play or h for human to play:c
# You Lose! Want to start a new game?
#
#             Enter r for Rock,
#                   s for Scissors,
#                   p for Paper
#
# Player 1: r
# Press c for computer to play or h for human to play:c
# Draw! try again
#
#             Enter r for Rock,
#                   s for Scissors,
#                   p for Paper
#
# Player 1: r
# Press c for computer to play or h for human to play:c
# You Lose! Want to start a new game?
#
#             Enter r for Rock,
#                   s for Scissors,
#                   p for Paper
#
# Player 1: r
# Press c for computer to play or h for human to play:c
# Congratulations, You Win! Want to start a new game?
#
#             Enter r for Rock,
#                   s for Scissors,
#                   p for Paper
#
# Player 1: r
# Press c for computer to play or h for human to play:c
# You Lose! Want to start a new game?
#
#             Enter r for Rock,
#                   s for Scissors,
#                   p for Paper
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11896/3445609843.py in <module>
#      15                   p for Paper
#      16             """)
# ---> 17       player_1 = input("Player 1: ")
#      18       player_type = input("Press c for computer to play or h for human to play:")
#      19
#
# ~\anaconda3\envs\studyenv\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1004                 "raw_input was called, but this frontend does not support input requests."
#    1005             )
# -> 1006         return self._input_request(
#    1007             str(prompt),
#    1008             self._parent_ident["shell"],
#
# ~\anaconda3\envs\studyenv\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1049             except KeyboardInterrupt:
#    1050                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1051                 raise KeyboardInterrupt("Interrupted by user") from None
#    1052             except Exception:
#    1053                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
